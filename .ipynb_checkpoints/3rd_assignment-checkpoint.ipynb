# %%
#1. Employee Performance Bonus Eligibility
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
highest_score=max(employees.values())
top_performer=[]
for name,score in employees.items():
    if score==highest_score:
        top_performer.append(name)
print(f"Top Performers Eligible for Bonus:{top_performer}score:({highest_score})")
# Out:
# Top Performers Eligible for Bonus:['Ravi', 'Kiran']score:(92)

# %%
#2.Search Query Keyword Analysis
import string
sentence="Buy mobile phone buy phone online"
string=sentence.lower()
query=string.translate(str.maketans('','',string.punctuation))
words=query.split()
count={}
for word in words:
    if word in count:
        count[word]+=1
    else:
        count[word]=1
print(count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       3 sentence="Buy mobile phone buy phone online"
#       4 string=sentence.lower()
# ----> 5 query=string.translate(str.maketans('','',string.punctuation))
#       6 words=query.split()
#       7 count={}
#
# AttributeError: type object 'str' has no attribute 'maketans'
